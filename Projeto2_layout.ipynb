# %% [markdown]
# # Projeto 2 - Ciência dos Dados

# %% [markdown]
# Nome: _____
#
# Nome: _____

# %% [markdown]
# Serão permitidos grupos de três pessoas, mas com uma rubrica mais exigente. Grupos deste tamanho precisarão fazer um questionário de avaliação de trabalho em equipe

# %% [markdown]
# ___
# # Classificador automático de sentimento

# %% [markdown]
# ## Preparando o ambiente no jupyter:

# %%
# %%capture

#Instalando o tweepy
# !pip install tweepy
# !pip install demoji

# %%
import tweepy
import math
import os.path
import pandas as pd
import json
import numpy as np
from random import shuffle

# %% [markdown]
# ## Função para limpar o texto

# %%
import re 

def cleanup(text):
    """
        Função de limpeza muito simples que troca alguns sinais básicos por espaços
    """
    import string
    punctuation = '[!-/.:?;@]' # Note que os sinais [] são delimitadores de um conjunto.
    pattern = re.compile(punctuation)
    nova_linha = '[\n]'
    text_subbed = re.sub(pattern, ' ', text)
    text_subbed = re.sub(nova_linha, " ", text_subbed)
    return text_subbed    

# def deEmojify(text):
    
#     emoji_pattern = re.compile("["
#                 u"\U0001F600-\U0001F64F"  # emoticons
#                 u"\U0001F300-\U0001F5FF"  # symbols & pictographs
#                 u"\U0001F680-\U0001F6FF"  # transport & map symbols
#                 u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
#                 u"\U00002702-\U000027B0"
#                 u"\U000024C2-\U0001F251"
#                 u"\U0001f926-\U0001f937"
#                 u'\U00010000-\U0010ffff'
#                 u"\u200d"
#                 u"\u2640-\u2642"
#                 u"\u2600-\u2B55"
#                 u"\u23cf"
#                 u"\u23e9"
#                 u"\u231a"
#                 u"\u3030"
#                 u"\ufe0f"
#     "]+", flags=re.UNICODE)
    
#     return (emoji_pattern.sub(r'', text))

# def tira_mention(text):
    
#     mention = "@"
#     for i in range(0, len(text)-1):
#         if mention in text[i]:
#             del(text[i])
#     return text

# %% [markdown]
# ___
# ## Autenticando no  Twitter
#
# * Conta: ***[Preencha aqui o id da sua conta. Ex: @fulano ]***

# %% [raw]
# #Dados de autenticação do twitter:
#
# #Coloque aqui o identificador da conta no twitter: @fulano
#
# #leitura do arquivo no formato JSON
# with open('auth.pass') as fp:
#     data = json.load(fp)
#
# #Configurando a biblioteca. Não modificar
# auth = tweepy.OAuthHandler(data['consumer_key'], data['consumer_secret'])
# auth.set_access_token(data['access_token'], data['access_token_secret'])

# %% [markdown]
# ___
# ## Etapas do projeto:

# %% [markdown]
# ### Escolha de um produto e coleta das mensagens

# %% [raw]
# #Produto escolhido:
# produto = 'pokemon'
#
# #Quantidade mínima de mensagens capturadas:
# n = 500
# #Quantidade mínima de mensagens para a base de treinamento:
# t = 300
#
# #Filtro de língua, escolha uma na tabela ISO 639-1.
# lang = 'pt'

# %% [markdown]
# Capturando os dados do twitter:

# %% [raw]
# #Cria um objeto para a captura
# api = tweepy.API(auth)
#
# #Inicia a captura, para mais detalhes: ver a documentação do tweepy
# i = 1
# msgs = []
#
# for msg in tweepy.Cursor(api.search, q=produto, lang=lang, tweet_mode='extended').items():
#     if (not msg.retweeted) and ('RT' not in msg.full_text):
#         msgs.append(msg.full_text.lower())
#         i += 1
#     if i > n:
#         break
#
# #Embaralhando as mensagens para reduzir um possível viés
# shuffle(msgs)

# %% [markdown]
# Salvando os dados em uma planilha Excel:

# %% [raw]
# #Verifica se o arquivo não existe para não substituir um conjunto pronto
# if not os.path.isfile('./{0}.xlsx'.format(produto)):
#
#     #Abre o arquivo para escrita
#     writer = pd.ExcelWriter('{0}.xlsx'.format(produto))
#
#     #divide o conjunto de mensagens em duas planilhas
#     dft = pd.DataFrame({'Treinamento' : pd.Series(msgs[:t])})
#     dft.to_excel(excel_writer = writer, sheet_name = 'Treinamento', index = False)
#
#     dfc = pd.DataFrame({'Teste' : pd.Series(msgs[t:])})
#     dfc.to_excel(excel_writer = writer, sheet_name = 'Teste', index = False)
#
#     #fecha o arquivo
#     writer.save()

# %% [markdown]
# ___
# ### Classificando as mensagens na coragem
#
# Esta etapa é manual. Faça a mesma pelo Excel.

# %% [markdown]
# ___
# ### Montando o Classificador Naive-Bayes
#
# Considerando apenas as mensagens da planilha Treinamento, ensine  seu classificador.

# %%
#Leitura do excel
pokemon_treino = pd.read_excel("pokemon_classificado.xlsx", "Treinamento")
pokemon_teste = pd.read_excel("pokemon_classificado.xlsx", "Teste")

# %%
pokemon_treino_texto = pd.Series(pokemon_treino["Treinamento"])
pokemon_treino_texto = pokemon_treino_texto.str.cat()
pokemon_treino_texto = cleanup(pokemon_treino_texto.lower())
# pokemon_treino_texto = deEmojify(pokemon_treino_texto)
lista_relativa = pokemon_treino_texto.split()
# lista_relativa = tira_mention(lista_relativa)
frequencia_absoluta = pd.Series(lista_relativa).value_counts()
frequencia_relativa = pd.Series(lista_relativa).value_counts(True)
frequencia_relativa
# Out:
# de                         0.031428
# pokémon                    0.026532
# e                          0.022110
# que                        0.021952
# o                          0.020373
# pokemon                    0.019109
# a                          0.014687
# eu                         0.014687
# co                         0.013424
# é                          0.013424
# https                      0.013424
# t                          0.013424
# um                         0.010739
# do                         0.010423
# pra                        0.010423
# no                         0.010265
# em                         0.009634
# com                        0.009476
# não                        0.009318
# go                         0.007265
# na                         0.006475
# meu                        0.006475
# uma                        0.006317
# me                         0.005843
# mas                        0.005370
# mais                       0.005212
# os                         0.005054
# da                         0.005054
# só                         0.004896
# se                         0.004580
#                              ...
# capoeira                   0.000158
# formato                    0.000158
# dizem                      0.000158
# dourada                    0.000158
# easy                       0.000158
# sr                         0.000158
# otários                    0.000158
# si                         0.000158
# rlx                        0.000158
# suco                       0.000158
# igormendonca42             0.000158
# rico                       0.000158
# possivelmente              0.000158
# willis                     0.000158
# pokemondetectivepikachu    0.000158
# american                   0.000158
# singers                    0.000158
# trade                      0.000158
# porque                     0.000158
# demonstrar                 0.000158
# grau                       0.000158
# omelhoralek                0.000158
# turma                      0.000158
# doctorwho                  0.000158
# professora                 0.000158
# regresso                   0.000158
# plantas                    0.000158
# naruto                     0.000158
# coloca                     0.000158
# culpa                      0.000158
# Length: 2261, dtype: float64

# %%
pokemon_teste
# Out:
#                                                  Teste  Relevante
# 0    @diaaaaasg kskskskskksksksskksks deve ter sido...          0
# 1    opinião nada popular mas pokémon let's go é o ...          0
# 2    @diogoserafimrg pokémon, qualquer jogo da séri...          0
# 3    um sorteio já é bom, agora imagina dois!? 😍👏😍\...          0
# 4    @lucasxld\n \n •primeira impressão: menino que...          0
# 5    rip minha amiga que fechou a semana com 24.9km...          1
# 6    caixa de sétimo dia não poderia ter sido melho...          0
# 7    dirigir ou jogar pokémon go? fazer os dois ao ...          1
# 8    @jimmyfucker farfetch n era a porra de um poke...          0
# 9    toda semana um evento no pokémon pra deixar os...          0
# 10   @molantpk mas sword &amp; shield terão as mecâ...          1
# 11   @yngdeja o mimikyu é um ghost pokemon que se f...          0
# 12   @kikorodrigo se você considera “pokémon” uma o...          0
# 13   chegar em casa tarde porque foi caçar pokémon&...          0
# 14   pokemon go é muito dificil por que que os poke...          1
# 15                    @maviigatinha eu jogo pokemon go          1
# 16           evoluiu na vdd é uma musica sobre pokemon          0
# 17   o nome da loja é o nome de um pokémon suave ht...          0
# 18   @danphrodite é bateria de sobre para jogar pok...          1
# 19   esqueci de deixar espaço de ovo pra recompensa...          0
# 20   eu sou bue engraçada e tenho 6 gerações de pok...          0
# 21   agora é esperar o sword shield dia 15 de novem...          1
# 22   @dinossarro102 eu nunca fui muito de pokemon, ...          0
# 23   @bxrdsofprey amigo você apagou aquela foto que...          0
# 24   jogando pokémon go no atendimento da unimed .:...          1
# 25                   @pahssion favorito/melhor pokemon          0
# 26    várias pessoas caçando pokémon no norte shopping          0
# 27   comecei a jogar pokemon go com uns amigos e es...          1
# 28   ah pois..quer dizer q eu ralo p caralho p ganh...          0
# 29   @cmonsendnudes @rafaellbss bem, acho que acaba...          0
# ..                                                 ...        ...
# 170  eu tava lendo sobre a história do cachecol e p...          0
# 171  @c_ruanvale @lucianozap @pokemon_drakrai @dane...          0
# 172  @evidals_ galera compra pokémon todo ano, tem ...          0
# 173  a apostila do teu colégio explica matéria com ...          0
# 174  vamos começar uma amizade no pokémon go! meu c...          1
# 175              alguém que venha procurar pokémon cmg          0
# 176           tirei tipo fogo! https://t.co/6idgry94x3          0
# 177  #pokemon #leaguecup neste sábado! confira maio...          0
# 178  mochila nas costas radinho na cintura bonezin ...          0
# 179  @giiantonacci @laguneeeex mais uma pra crackol...          0
# 180  pokémon | anime chega em novembro e é um reboo...          0
# 181      foi o pokemon certeza https://t.co/6g1ofwnhgn          0
# 182  acabei de sacar a temporada 19, 20 e 21 de pok...          0
# 183  me tornei quem eu mais temia\n a pessoa que nã...          0
# 184  wtf esse ultimo ep do pokemon cara muuuito rep...          0
# 185                      casal de velho jogano pokemon          0
# 186  primeiro empreendimento foi qnd henrique ganha...          0
# 187  @gritodally @nxmelessbear tudo no tumblr!! ach...          0
# 188  entrei no mundo dos animes essa semana com att...          0
# 189  eu com várias coisas pra fazer jogando pokémon...          1
# 190  @kediny3 @piltovereyes @bugadacoisa my two cen...          0
# 191  @tutupieri fato. \n eu nos 33 ia dar aula com ...          0
# 192  caralho... tô mal agora... nem vonta de jogar ...          0
# 193  e se no mundo pokémon, todos aqueles campeonat...          0
# 194  @zelune que porra eh essa meu deus parece um p...          0
# 195  @danielreen fica aí a dúvida, fã de pokémon nã...          0
# 196  concordo 100% pois eu trabalho é pra fazer cos...          0
# 197  @littlemirai @fdstorugo qual de vcs vai jogar ...          0
# 198  se jogar no forno pega pokemon tipo fogo https...          0
# 199                  sair de casa pra jogar pokemon go          1
#
# [200 rows x 2 columns]

# %% [markdown]
# ___
# ### Verificando a performance
#
# Agora você deve testar o seu classificador com a base de Testes.

# %% [markdown]
# ___
# ### Concluindo

# %% [markdown]
# ## Aperfeiçoamento:
#
# Os trabalhos vão evoluir em conceito dependendo da quantidade de itens avançados:
#
# * Limpar: \n, :, ", ', (, ), etc SEM remover emojis
# * Corrigir separação de espaços entre palavras e emojis ou emojis e emojis
# * Propor outras limpezas e transformações que não afetem a qualidade da informação ou classificação
# * Criar categorias intermediárias de relevância baseadas na probabilidade: ex.: muito relevante, relevante, neutro, irrelevante, muito irrelevante (3 categorias: C, mais categorias conta para B)
# * Explicar por que não posso usar o próprio classificador para gerar mais amostras de treinamento
# * Propor diferentes cenários para Naïve Bayes fora do contexto do projeto
# * Sugerir e explicar melhorias reais com indicações concretas de como implementar (indicar como fazer e indicar material de pesquisa)
# * Montar um dashboard que periodicamente realiza análise de sentimento e visualiza estes dados

# %% [markdown]
# # Referências

# %% [markdown]
# [Naive Bayes and Text Classification](https://arxiv.org/pdf/1410.5329.pdf)  **Mais completo**
#
# [A practical explanation of a Naive Bayes Classifier](https://monkeylearn.com/blog/practical-explanation-naive-bayes-classifier/) **Mais simples**
